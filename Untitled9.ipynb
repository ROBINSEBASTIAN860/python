# %% [markdown]
# <a href="https://colab.research.google.com/github/ROBINSEBASTIAN860/python/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-323c131d-9d0b-457e-a08c-fcfb3be168b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-323c131d-9d0b-457e-a08c-fcfb3be168b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-9e294392-c282-4c28-b2c4-2f108951bc41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e294392-c282-4c28-b2c4-2f108951bc41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
teamgoals={
    'teams':['spain','england'],
    'goals':[2,4]
}
teamgoalsdf= pd.DataFrame(teamgoals)
print(teamgoalsdf)
# Out:
#      teams  goals
# 0    spain      2
# 1  england      4

# %%
import pandas as pd
teamgoals={
    'players':['messi','ronaldo'],
    'teams':['arg','por']
}
teamgoalsdf= pd.DataFrame(teamgoals)
print(teamgoalsdf)
# Out:
#    players teams
# 0    messi   arg
# 1  ronaldo   por

# %%
import pandas as ml
marklist={
    'subject':['maths','science'],
    'marks':[45,35]
}
marklist= ml.DataFrame(marklist)
print(marklist)
# Out:
#    subject  marks
# 0    maths     45
# 1  science     35

# %%
import pandas
dataframe=pandas.read_csv("Supermarket_sales.csv")
print(dataframe)
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
import pandas
dataframe=pandas.read_csv("teams_and_leagues.csv")
print(dataframe)
# Out:
#        url                   league_name
# 0      241       Spain Primera Division
# 1       11       English Premier League
# 2        5       English Premier League
# 3      243       Spain Primera Division
# 4        1       English Premier League
# ...    ...                           ...
# 1075   326            Turkish Süper Lig
# 1076   190              Italian Serie A
# 1077   448       Spain Primera Division
# 1078     8  English League Championship
# 1079  1799       English Premier League
#
# [1080 rows x 2 columns]

# %%
import pandas
dataframe=pandas.read_csv("teams_and_leagues.csv")
print(dataframe.head)
# Out:
# <bound method NDFrame.head of        url                   league_name
# 0      241       Spain Primera Division
# 1       11       English Premier League
# 2        5       English Premier League
# 3      243       Spain Primera Division
# 4        1       English Premier League
# ...    ...                           ...
# 1075   326            Turkish Süper Lig
# 1076   190              Italian Serie A
# 1077   448       Spain Primera Division
# 1078     8  English League Championship
# 1079  1799       English Premier League
#
# [1080 rows x 2 columns]>

# %%
dataframe['City']
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
dataframe[[
    'City','Branch']]
# Out:
#           City Branch
# 0       Yangon      A
# 1    Naypyitaw      C
# 2       Yangon      A
# 3       Yangon      A
# 4       Yangon      A
# ..         ...    ...
# 995  Naypyitaw      C
# 996   Mandalay      B
# 997     Yangon      A
# 998     Yangon      A
# 999     Yangon      A
#
# [1000 rows x 2 columns]

# %%
print(dataframe.index)
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
for i in dataframe.index:
  print((dataframe.City[i],dataframe.Branch[i]))
# Out:
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Naypyitaw', 'C')
# ('Yangon', 'A')
# ('Yangon', 'A')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Naypyitaw', 'C')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Mandalay', 'B')
# ('Naypyitaw', 'C')
# ('Naypyitaw', 'C')
# ...

# %%
from google.colab import files
players_20.csv=files.upload()
# Out:
#      <input type="file" id="files-50f18976-9430-440f-960e-10ae4034c2b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50f18976-9430-440f-960e-10ae4034c2b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fifadataframe = pandas.read_csv("players_20.csv")
max_overall=fifadataframe.overall.max()
max_overall_loc = fifadataframe.overall.idxmax()
person=fifadataframe.loc[max_overall_loc]
print(person.long_name,"has the highest overall of",max_overall)

# %%
fifadataframe = pandas.read_csv("players_20.csv")
min_age=fifadataframe.overall.min()
min_age_loc = fifadataframe.age.idxmax()
person=fifadataframe.loc[min_age_loc]
print(person.long_name,"has the age of",min_age)
# Out:
# Cristian Fernando Muñoz Hoffman has the age of 48

# %%
fifadataframe = pandas.read_csv("players_20.csv")
min_age=fifadataframe.overall.idxmin()
min_age_loc = fifadataframe.age.idxmax()
person=fifadataframe.loc[min_age_loc]
print(person.long_name,"has the age of",min_age)
# Out:
# Cristian Fernando Muñoz Hoffman has the age of 18235

# %%
playercount=fifadataframe.overall.mean()
print(overall_mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-a6b47ac7d285> in <module>
#       1 playercount=fifadataframe.overall.mean()
# ----> 2 print(overall_average)
#
# NameError: name 'overall_average' is not defined

# %%
for i in fifadataframe.index:
  if fifadataframe.club[i] == "FC Barcelona":
    print(fifadataframe.short_name[i])
